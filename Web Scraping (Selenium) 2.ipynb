# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.12)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\hp\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.10 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.2.2)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9; python_version < "3.11" in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.20)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get("http://www.naukri.com/")

# %%
designation=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[1]/div/div/div/input')
designation.send_keys('Data Analyst')

location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys("Bangalore")

search=driver.find_element(By.XPATH,'//html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data. This task will be done in following steps:

# %%
job_title=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')[0:10]:
    job_title.append(i.text)
    
# Scrapping job location from the webpage
job_location=[]
for i in driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]//span')[0:10]:
    job_location.append(i.text)

# Scrapping Company Name from the webpage
company_name=[]
for i in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    company_name.append(i.text)

# Scrapping Experience from the webpage
experience_required=[]
for i in driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')[0:10]:
    experience_required.append(i.text)

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience_required':experience_required})
df
# Out:
#                                            Job_Title  \
# 0  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 1  Call For Clinical Data Analyst - Hyd/Bangalore...
# 2                                       Data Analyst
# 3                                    HR Data Analyst
# 4                Payroll Transformation Data Analyst
# 5                                Senior Data Analyst
# 6                                       Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                                       Data Analyst
#
#                                         Job_Location  \
# 0  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 1  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                       Bangalore/Bengaluru, Chennai
# 6  Bangalore/Bengaluru, Mangaluru/Mangalore, Pune...
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                           Company_Name Experience_required
# 0                            Cognizant             3-8 Yrs
# 1                            Cognizant             6-9 Yrs
# 2                                  Jar             0-4 Yrs
# 3                         Hitachi Ltd.             3-6 Yrs
# 4                    Arrow Electronics             3-7 Yrs
# 5                           Latentview             3-6 Yrs
# 6             Coresight Research, Inc.             4-8 Yrs
# 7                               Varite             2-5 Yrs
# 8  RYSTAD ENERGY INDIA PRIVATE LIMITED             0-3 Yrs
# 9                                  ANZ            7-12 Yrs

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# you have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %%
job_title=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')[0:10]:
    job_title.append(i.text)
    
# Scrapping job location from the webpage
job_location=[]
for j in driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]//span')[0:10]:
    job_location.append(j.text)

# Scrapping Company Name from the webpage
company_name=[]
for k in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    company_name.append(k.text)

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name})
df
# Out:
#                                            Job_Title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                              Senior Data Scientist
# 8            Data Scientist: Artificial Intelligence
# 9                   Data Scientist - Computer Vision
#
#                                         Job_Location             Company_Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...                  Mphasis
# 3  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 4                  Bangalore/Bengaluru, Mumbai, Pune               CitiusTech
# 5  Bangalore/Bengaluru, New Delhi, Pune, Gurgaon/...            ZS Associates
# 6  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...            Tech Mahindra
# 7    Bangalore/Bengaluru, Mumbai, New Delhi, Chennai  Boston Consulting Group
# 8                                Bangalore/Bengaluru                      IBM
# 9                                Bangalore/Bengaluru                  Walmart

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p')
location.click()

# %%
salary=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
salary.click()

# %%
jtitle=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')[0:10]:
    jtitle.append(i.text)
    
# Scrapping job-location from the webpage
jloc=[]
for j in driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]//span')[0:10]:
    jloc.append(j.text)

# Scrapping Company name from the webpage
comp=[]
for k in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    comp.append(k.text)
    
# Scrapping Experience required from the webpage
exp=[]
for l in  driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')[0:10]:
    exp.append(l.text)

# %%
df=pd.DataFrame({'Job_Title':jtitle,'Job_Location':jloc,'Company_Name':comp,'Experience required':exp})
df
# Out:
#                                            Job_Title  \
# 0                            Data Science Specialist
# 1                                 Module Lead - BIDW
# 2                       Data Scientist/AIML Engineer
# 3                 Geospatial Data Engineer/Scientist
# 4  Python Programming Language Data Science Pract...
# 5                          Data Science/ ML freshers
# 6                  Data Scientist - Engine Algorithm
# 7                                     Data Scientist
# 8                Scientific Computing (Proactive SO)
# 9                                     Data Scientist
#
#                                         Job_Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1                                Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 6  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 7                 Bangalore/Bengaluru, Noida, Nagpur
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                   Company_Name Experience required
# 0                    Accenture             2-4 Yrs
# 1                      Mphasis             5-8 Yrs
# 2                       upGrad             0-2 Yrs
# 3    Louis Dreyfus Commodities            5-10 Yrs
# 4                    Accenture             4-6 Yrs
# 5  CliqHR Recruitment Services             0-1 Yrs
# 6                 Primo Hiring             1-3 Yrs
# 7                  GlobalLogic            8-10 Yrs
# 8                          CGI             3-7 Yrs
# 9                      Infosys             2-7 Yrs

# %% [markdown]
# # 4 Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('http://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('Sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
# Scrapping Brand detail from the webpage
brand=[]
for i in driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
    brand.append(i.text)

# Scrapping Product Description from the webpage
pro1=[]
for j in driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]'):
    pro1.append(j.text)
    
pro2=[]
for j in driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
    pro2.append(j.text)
    
pro_des=pro1+pro2

# Scrapping Price from the webpage
price=[]
for k in driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
    price.append(k.text)

# Scrapping Discount from the webpage
dis=[]
for l in driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]'):
    dis.append(l.text)

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':pro_des,'Price':price,'Discount':dis})
df
# Out:
#                 Brand                                Product Description  \
# 0              PIRASO              UV Protection Aviator Sunglasses (54)
# 1              PIRASO             UV Protection Wayfarer Sunglasses (55)
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3   SHAAH COLLECTIONS                UV Protection Round Sunglasses (54)
# 4   SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 5                MODE       UV Protection Aviator Sunglasses (Free Size)
# 6   SHAAH COLLECTIONS              UV Protection Aviator Sunglasses (54)
# 7              OAKLEY                               Rectangular Sunglass
# 8          LIZA ANGEL      UV Protection Wayfarer Sunglasses (Free Size)
# 9   SHAAH COLLECTIONS   UV Protection Rectangular Sunglasses (Free Size)
# 10  SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 11             PIRASO          UV Protection Rectangular Sunglasses (52)
# 12             SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 13           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 14             PIRASO              UV Protection Aviator Sunglasses (58)
# 15             PIRASO       UV Protection Aviator Sunglasses (Free Size)
# 16           Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 17          ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)
# 18     kingsunglasses   UV Protection Rectangular Sunglasses (Free Size)
# 19             PIRASO            UV Protection Butterfly Sunglasses (60)
# 20           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 21           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 22  SHAAH COLLECTIONS                UV Protection Round Sunglasses (52)
# 23             OAKLEY                               Rectangular Sunglass
# 24          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 25           Fastrack   UV Protection Wrap-around Sunglasses (Free Size)
# 26             Sewell  Mirrored, Night Vision, UV Protection, Riding ...
# 27             PIRASO             UV Protection Wayfarer Sunglasses (32)
# 28          New Specs          UV Protection Oval Sunglasses (Free Size)
# 29           Fastrack        UV Protection Shield Sunglasses (Free Size)
# 30              NuVew             UV Protection Wayfarer Sunglasses (57)
# 31             PIRASO              UV Protection Aviator Sunglasses (50)
# 32           Fastrack              UV Protection Aviator Sunglasses (58)
# 33  SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 34              NuVew    UV Protection, Mirrored Aviator Sunglasses (57)
# 35             OAKLEY                              Retro Square Sunglass
# 36          ROYAL SON  Polarized, UV Protection Wayfarer Sunglasses (61)
# 37           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 38          ROYAL SON                   Mirrored Aviator Sunglasses (55)
# 39             PIRASO           UV Protection Over-sized Sunglasses (65)
#
#       Price Discount
# 0      ₹237  85% off
# 1      ₹237  85% off
# 2      ₹799  20% off
# 3      ₹179  86% off
# 4      ₹179  86% off
# 5      ₹179  77% off
# 6      ₹179  82% off
# 7   ₹12,409  10% off
# 8      ₹199  50% off
# 9      ₹179  82% off
# 10     ₹179  86% off
# 11     ₹246  84% off
# 12     ₹283  78% off
# 13     ₹679  15% off
# 14     ₹305  88% off
# 15     ₹296  81% off
# 16     ₹639  20% off
# 17     ₹561  71% off
# 18     ₹199  80% off
# 19     ₹399  84% off
# 20     ₹759  15% off
# 21     ₹719  20% off
# 22     ₹179  87% off
# 23  ₹10,159  10% off
# 24     ₹264  89% off
# 25     ₹719  20% off
# 26     ₹279  81% off
# 27     ₹237  85% off
# 28     ₹189  81% off
# 29     ₹719  20% off
# 30     ₹185  78% off
# 31     ₹296  81% off
# 32   ₹1,169  10% off
# 33     ₹195  88% off
# 34     ₹198  73% off
# 35   ₹6,739  10% off
# 36     ₹524  73% off
# 37     ₹869  13% off
# 38     ₹339  77% off
# 39     ₹383  85% off

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-128-gb/p/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8IBG6BS&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_5_na_na_na&fm=organic&iid=88605bfc-b0ce-40e8-9bc6-b5de4c7ffbb9.MOBFWQ6BKRYBP5X8.SEARCH&ppt=hp&ppn=homepage&ssid=e3kwwcgvds0000001664652557939&qH=f6cdfdaa9f3c23f3')

# %%
rate1=[]
rate2=[]
summary=[]
f_rev=[]

# for scrapping data from different pages to get first 100 reviews, defining Start & End of the page
start=0
end=15
for page in range(start,end):
    
# Scrapping rating from different pages 
    for i in driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]'):
        rate1.append(i.text)
        
    for i in driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1rdVr6 _1BLPMq"]'):
        rate2.append(i.text)
    rate=rate1+rate2

# Scrapping Review Summary from different pages
    for j in driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]'):
        summary.append(j.text)
        
# Scrapping Full Review from different pages
    for k in driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]'):
        f_rev.append(k.text)
        
#scraping the list of reviews data from different pages
    nxt_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
    try:
        driver.get(nxt_button[1].get_attribute('href')) #getting the link from the list for next page
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# converting scrapped data for first 100 reviews into DataFrame
review=pd.DataFrame({'Rating':rate,'Review Summary':summary,'Full Review':f_rev})
review.head(100)
# Out:
#    Rating         Review Summary  \
# 0       5         Simply awesome
# 1       4        Value-for-money
# 2       5       Perfect product!
# 3       5    Best in the market!
# 4       5      Worth every penny
# ..    ...                    ...
# 95      5      Worth every penny
# 96      5              Excellent
# 97      5  Mind-blowing purchase
# 98      5              Excellent
# 99      5               Terrific
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   I'm Really happy with the product\nDelivery wa...
# 2   Amazing phone with great cameras and better ba...
# 3   Great iPhone very snappy experience as apple k...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  It is better to buy iPhone 11 over iPhone 12 i...
# 96  A perfect phone and a good battery super camer...
# 97  awesome Phone Smooth Touch Too good Sexyy look...
# 98  It was amazing experience for me. Honestly i a...
# 99  I bought iPhone 11 On March 2021, And I am Wri...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('http://www.flipkart.com/')

# %%
close=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
close.click()

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
#introducing list for brand, product description, price & discount
brand=[]
prod1=[]
prod2=[]
price=[]
discount=[]

# for scrapping data from different pages to get first 100 reviews, defining Start & End of the page
for page in range(0,5):
    
# Scrapping brand list from different pages 
    for i in driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
        brand.append(i.text)
        
# Scrapping product description from different pages 
    for j in driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
        prod1.append(j.text)
        
    for c in driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]'):
        prod2.append(c.text)
    prod=prod1+prod2
    
# Scrapping price from different pages 
    for k in driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
        price.append(k.text)
        
# Scrapping discount from different pages 
    for l in driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]'):
        discount.append(l.text)
        
#scraping the required data from different pages
    nxt_button=driver.find_elements(By.XPATH,'//a[@class="ge-49M _2Kfbh8"]')
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))
        
# converting scrapped data for first 100 reviews into DataFrame
Sneaker_data=pd.DataFrame({'Brand':brand,'Product Description':prod,'Price':price,'Discount':discount})
Sneaker_data.head(100)
# Out:
#            Brand                                Product Description   Price  \
# 0          Krors  Mesh| Ultralightweight | Comfortable | Breatha...    ₹499
# 1      RED CHIEF                                     Casual For Men  ₹2,726
# 2         BRUTON  Lightweight Pack Of 1 Trendy Sneakers Sneakers...    ₹259
# 3         BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men    ₹470
# 4         Labbin                                   Sneakers For Men    ₹499
# ..           ...                                                ...     ...
# 95  K- FOOTLANCE  Casual Sneakers Canvas Shoes For Men Sneakers ...    ₹399
# 96        Kraasa  NK Court Royale AC Canvas Women's Shoes Sneake...    ₹624
# 97     Deals4you                                   Sneakers For Men    ₹389
# 98  Robbie jones                                   Sneakers For Men    ₹549
# 99          NIKE                                   Sneakers For Men  ₹4,001
#
#    Discount
# 0   50% off
# 1   35% off
# 2   56% off
# 3   63% off
# 4   50% off
# ..      ...
# 95  60% off
# 96  37% off
# 97  61% off
# 98  45% off
# 99  10% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe as shown in the below image

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('http://www.myntra.com/shoes')

# %%
# Futher can not able to open inspect option as can able to right click on site

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys('Laptop')

# %%
search_button=driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')
search_button.click()

# %%
cpu_type=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[13]/span/a/div/label/i')
cpu_type.click()

# %%
title=[]
for i in driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')[0:10]:
    title.append(i.text)
    
# Scrapping product price from the webpage
price=[]
for j in driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')[0:10]:
    price.append(j.text)

# converting scrapped data for first 10 Laptops data into DataFrame
Laptop=pd.DataFrame({'Title':title,'Price':price}) 
Laptop.head(10)
# Out:
#                                                Title   Price
# 0  Sponsored\n(Renewed) Lenovo Ideapad 330S-15IKB...  42,999
# 1  Sponsored\n(Renewed) Lenovo Yoga 730-13IKB 81C...  57,799
# 2  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...  93,290
# 3  HP Pavilion x360 11th Gen Intel Core i7 14 inc...  80,990
# 4  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...  79,990
# 5  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...  67,990
# 6  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....  77,990
# 7  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...  98,290
# 8  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...  86,990
# 9  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...  82,490

# %%
# As Directed by mentor question number 9 should be skipped

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.

# %%
driver=webdriver.Chrome(r"D:\driver\chromedriver.exe")

# %%
driver.get('https://www.ambitionbox.com/')

# %%
salary=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[3]/span')
salary.click()

# %%
browser=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[3]/div/ul/li[1]/div/div[2]/p')
browser.click()

# %%
job=driver.find_element(By.XPATH,'//input[@class="tt-input"]')
job.send_keys('Data Scientist')

# %%
select=driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div')
select.click()

# %%
comp=[]
for i in driver.find_elements(By.XPATH,'//div[@class="company-info"]/a'):
    comp.append(i.text.split("\n"))
    
company=sum(comp,[])
del company[1:20:2]

bsal=[]
for a in driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]/span'):
    bsal.append(a.text.replace('(','').replace(')',''))
    
avgsal=[]
for b in driver.find_elements(By.XPATH,'//p[@class="averageCtc"]'): 
    avgsal.append(b.text)
    
min_sal=[]
max_sal=[]
for c in driver.find_elements(By.XPATH,'//div[@class="value body-medium"]'): 
    min_sal.append(c.text)
    max_sal.append(c.text)
del min_sal[1:20:2]
del max_sal[0:20:2]


exp=[]
for d in driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]'): 
    exp.append(d.text.split('('))
    
req_exp=sum(exp,[]) 
del req_exp[1:20:2]

df=pd.DataFrame({'Company Name':company,'Total Salary Record':bsal,'Average Salary':avgsal,'Minimum Salary':min_sal,'Maximum Salary':max_sal,'Experience Required':req_exp})
df
# Out:
#                  Company Name    Total Salary Record Average Salary  \
# 0                     Walmart   based on 24 salaries        ₹ 32.2L
# 1                    Ab Inbev   based on 59 salaries        ₹ 19.8L
# 2                       Optum   based on 49 salaries        ₹ 16.4L
# 3                          ZS   based on 35 salaries        ₹ 15.9L
# 4           Fractal Analytics  based on 118 salaries        ₹ 15.5L
# 5           Sigmoid Analytics   based on 10 salaries        ₹ 14.7L
# 6             Tiger Analytics   based on 70 salaries        ₹ 14.6L
# 7  Legato Health Technologies   based on 11 salaries        ₹ 14.5L
# 8                        HSBC   based on 10 salaries        ₹ 14.0L
# 9                    Tredence   based on 14 salaries        ₹ 13.9L
#
#   Minimum Salary Maximum Salary  Experience Required
# 0        ₹ 25.0L        ₹ 45.0L  3-4 yrs experience
# 1        ₹ 15.0L        ₹ 26.0L  2-4 yrs experience
# 2        ₹ 11.0L        ₹ 22.6L  2-4 yrs experience
# 3        ₹ 11.0L        ₹ 22.0L  1-2 yrs experience
# 4         ₹ 9.0L        ₹ 23.0L  2-4 yrs experience
# 5        ₹ 12.7L        ₹ 19.7L     1 yr experience
# 6         ₹ 9.0L        ₹ 20.0L  2-4 yrs experience
# 7        ₹ 11.0L        ₹ 20.0L    4 yrs experience
# 8        ₹ 12.0L        ₹ 18.0L    4 yrs experience
# 9         ₹ 8.8L        ₹ 17.5L    3 yrs experience
